# %%
import numpy as np
import pylab as pl

from pykalman.datasets import load_robot
from pykalman import KalmanFilter

# Load data and initialize Kalman Filter
data = load_robot()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-74d9a1cf42fa> in <module>()
#       2 import pylab as pl
#       3
# ----> 4 from pykalman.datasets import load_robot
#       5 from pykalman import KalmanFilter
#       6
#
# ImportError: No module named pykalman.datasets

# %%
import pykalman
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-4-1d51bd5a40f5> in <module>()
# ----> 1 import pykalman
#
# ImportError: No module named pykalman
